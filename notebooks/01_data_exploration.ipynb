# %% [markdown]
# # Data Exploration
# The goal of this notebook is to unnderstand the Istanbul weather dataset, clean it and remove unnecessary attributes, and eventually prepare it for training the deep learning model.

# %%
# Import libraries
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Open csv as DF
df = pd.read_csv('/content/istanbul_weather_last_10_years.csv')
df.head()
# Out:
#          time  tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# 0  2015-06-22  20.6  18.3  22.9   NaN   NaN   NaN  25.9   NaN   NaN   NaN
# 1  2015-06-23  21.8  19.0  25.0   NaN   NaN   NaN  20.2   NaN   NaN   NaN
# 2  2015-06-24  21.8  19.0  25.8   NaN   NaN   NaN  10.2   NaN   NaN   NaN
# 3  2015-06-25  21.9  17.0  26.1   NaN   NaN   NaN  11.9   NaN   NaN   NaN
# 4  2015-06-26  22.3  19.5  26.0   NaN   NaN   NaN  11.1   NaN   NaN   NaN

# %%
# Create new df including necessary attrebutes
new_df = df[['time', 'tavg', 'tmin', 'tmax', 'wspd']]
new_df.head()
# Out:
#          time  tavg  tmin  tmax  wspd
# 0  2015-06-22  20.6  18.3  22.9  25.9
# 1  2015-06-23  21.8  19.0  25.0  20.2
# 2  2015-06-24  21.8  19.0  25.8  10.2
# 3  2015-06-25  21.9  17.0  26.1  11.9
# 4  2015-06-26  22.3  19.5  26.0  11.1

# %%
# Rename columns
new_df.rename(columns={'time': 'date', 'tavg': 'avg_temp', 'tmin': 'min_temp', 'tmax': 'max_temp', 'wspd': 'wind_speed'}, inplace=True)
new_df.head()
# Out:
# /tmp/ipython-input-21-2688344452.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns={'time': 'date', 'tavg': 'avg_temp', 'tmin': 'min_temp', 'tmax': 'max_temp', 'wspd': 'wind_speed'}, inplace=True)
#          date  avg_temp  min_temp  max_temp  wind_speed
# 0  2015-06-22      20.6      18.3      22.9        25.9
# 1  2015-06-23      21.8      19.0      25.0        20.2
# 2  2015-06-24      21.8      19.0      25.8        10.2
# 3  2015-06-25      21.9      17.0      26.1        11.9
# 4  2015-06-26      22.3      19.5      26.0        11.1

# %%
# Find missing values
new_df.isnull().sum()
# Out:
# date          0
# avg_temp      0
# min_temp      3
# max_temp      3
# wind_speed    0
# dtype: int64

# %%
# fill missing values with forward fill (last known value)
new_df.fillna(method='ffill', inplace=True)
new_df.isnull().sum()
# Out:
# /tmp/ipython-input-23-3772582104.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df.fillna(method='ffill', inplace=True)
# /tmp/ipython-input-23-3772582104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.fillna(method='ffill', inplace=True)
# date          0
# avg_temp      0
# min_temp      0
# max_temp      0
# wind_speed    0
# dtype: int64

# %%
# Check duplicated values
new_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check data types
new_df.dtypes
# Out:
# date           object
# avg_temp      float64
# min_temp      float64
# max_temp      float64
# wind_speed    float64
# dtype: object

# %%
# Convert `date` data type from object to datetime
new_df['date'] = pd.to_datetime(new_df['date'])
new_df.dtypes
# Out:
# /tmp/ipython-input-26-2561780317.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['date'] = pd.to_datetime(new_df['date'])
# date          datetime64[ns]
# avg_temp             float64
# min_temp             float64
# max_temp             float64
# wind_speed           float64
# dtype: object

# %%
# Set date as index
new_df.set_index('date', inplace=True)
new_df.head()
# Out:
#             avg_temp  min_temp  max_temp  wind_speed
# date
# 2015-06-22      20.6      18.3      22.9        25.9
# 2015-06-23      21.8      19.0      25.0        20.2
# 2015-06-24      21.8      19.0      25.8        10.2
# 2015-06-25      21.9      17.0      26.1        11.9
# 2015-06-26      22.3      19.5      26.0        11.1

# %%
# Save cleaned dataset
new_df.to_csv('cleaned_weather_data')
